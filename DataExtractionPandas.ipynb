# %% [markdown]
# <a href="https://colab.research.google.com/github/NafisIrtija/AutomationUsingPython/blob/main/DataExtractionPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Extracting a table from HTML

# %%
episodes = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
len(episodes)
# Out:
# 24

# %%
episodes[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
# ...

# %% [markdown]
# ## Extracting .csv files

# %%
df_laliga23_24 = pd.read_csv('https://football-data.co.uk/mmz4281/2324/SP1.csv')

# %%
df_laliga23_24
# Out:
#      Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1  11/08/2023  18:30      Almeria    Vallecano     0     2   A     0
# 1    SP1  11/08/2023  21:00      Sevilla     Valencia     1     2   A     0
# 2    SP1  12/08/2023  16:00     Sociedad       Girona     1     1   D     1
# 3    SP1  12/08/2023  18:30   Las Palmas     Mallorca     1     1   D     1
# 4    SP1  12/08/2023  20:30   Ath Bilbao  Real Madrid     0     2   A     0
# ..   ...         ...    ...          ...          ...   ...   ...  ..   ...
# 375  SP1  25/05/2024  20:00  Real Madrid        Betis     0     0   D     0
# 376  SP1  26/05/2024  13:00       Getafe     Mallorca     1     2   A     0
# 377  SP1  26/05/2024  15:15        Celta     Valencia     2     2   D     0
# 378  SP1  26/05/2024  15:15   Las Palmas       Alaves     1     1   D     0
# 379  SP1  26/05/2024  20:00      Sevilla    Barcelona     1     2   A     1
#
# ...

# %%
df_laliga23_24.rename(columns={'FTHG':'home_goals',
                               'FTAG':'away_goals'})
# Out:
#      Div        Date   Time     HomeTeam     AwayTeam  home_goals  away_goals  \
# 0    SP1  11/08/2023  18:30      Almeria    Vallecano           0           2
# 1    SP1  11/08/2023  21:00      Sevilla     Valencia           1           2
# 2    SP1  12/08/2023  16:00     Sociedad       Girona           1           1
# 3    SP1  12/08/2023  18:30   Las Palmas     Mallorca           1           1
# 4    SP1  12/08/2023  20:30   Ath Bilbao  Real Madrid           0           2
# ..   ...         ...    ...          ...          ...         ...         ...
# 375  SP1  25/05/2024  20:00  Real Madrid        Betis           0           0
# 376  SP1  26/05/2024  13:00       Getafe     Mallorca           1           2
# 377  SP1  26/05/2024  15:15        Celta     Valencia           2           2
# 378  SP1  26/05/2024  15:15   Las Palmas       Alaves           1           1
# 379  SP1  26/05/2024  20:00      Sevilla    Barcelona           1           2
#
# ...

# %% [markdown]
# ## Extract table from .pdf files

# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !apt install ghostscript python3-tk
# !pip install 'PyPDF2<3.0'
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ghostscript is already the newest version (9.55.0~dfsg1-0ubuntu5.7).
# python3-tk is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
import camelot
import pandas as pd

# %%
tables = camelot.read_pdf('https://sedl.org/afterschool/toolkits/science/pdf/ast_sci_data_tables_sample.pdf', pages='2')

# %%
len(tables)
# Out:
# 2

# %%
tables.export('data.csv', f='csv', compress=True)

# %%
tables[0].to_csv('data.csv')

# %%
pd.read_csv('data.csv')
# Out:
#     Speed (mph)           Driver                         Car  \
# 0       407.447  Craig Breedlove           Spirit of America
# 1       413.199        Tom Green            Wingfoot Express
# 2       434.220       Art Arfons               Green Monster
# 3       468.719  Craig Breedlove           Spirit of America
# 4       526.277  Craig Breedlove           Spirit of America
# 5       536.712       Art Arfons               Green Monster
# 6       555.127  Craig Breedlove  Spirit of America, Sonic 1
# 7       576.553       Art Arfons               Green Monster
# 8       600.601  Craig Breedlove  Spirit of America, Sonic 1
# 9       622.407    Gary Gabelich                  Blue Flame
# 10      633.468    Richard Noble                    Thrust 2
# 11      763.035       Andy Green                  Thrust SSC
# 12          NaN              NaN                         NaN
#
#            Engine\nDate  Unnamed: 4
# 0        GE J47\n8/5/63         NaN
# ...
